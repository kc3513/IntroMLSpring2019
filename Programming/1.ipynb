# %%
import numpy as np
import matplotlib.pyplot as plot

kk = np.linspace(0,2,100)
yy = np.sin(2*np.pi*kk)

plot.plot(kk,yy)

epsilon = np.random.normal(0,0.1,50)

x = np.linspace(0,2,50)
y = np.sin(2*np.pi*x) + epsilon

plot.plot(x,y,'o')
